# %%
try:
    shell = get_ipython()
    shell.enable_pylab("inline")
except NameError:
    pass

import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
np = numpy
plt = pyplot
            
from IPython.display import display
from IPython.core.pylabtools import figsize, getfigs
import IPython
from pylab import *
from numpy import *
import PIL
from PIL import Image

# %%
import os
import glob
import numpy as np
import operator
for i in :
    images = sorted(glob.iglob('./data/training/'))
    
#training_image_filenames = sorted(glob.iglob('./data/training/*.pgm'))
#image = sorted(glob.iglob('./data/training/subject01.noglasses.pgm',))
#training_image_filenames = sorted(glob.iglob('./data/training/*.pgm'))
#imgmat = np.matrix(training_image_filenames)
#scipy.misc.imread(data/training/subject01.glasses.pgm)
#imgmat1 = np.matrix(image)
#print imgmat.shape
#print imgmat.size
# Out:
# (1, 110)
# 110

# %%
img = Image.open('./data/test/subject01.centerlight.pgm')
imggray = img.convert('LA')
plt.figure(figsize=(4, 4))
plt.imshow(imggray);
print img.size
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat)
print imgmat
print imgmat.shape
# Out:
# (195, 231)
# [[ 255.  255.  255. ...,  255.  255.  255.]
#  [ 255.  255.  255. ...,  255.  255.  255.]
#  [ 255.  255.  255. ...,  255.  255.  255.]
#  ...,
#  [ 255.  255.  255. ...,  255.  255.  255.]
#  [ 255.  255.  255. ...,  255.  255.  255.]
#  [ 255.  255.  255. ...,  255.  255.  255.]]
# (231, 195)

# %%
X = numpy.array([imread(i, True).flatten() for i in jpgs])

# %%
scipy.misc.imread?
# Out:
# Object `scipy.misc.imread` not found.

# %%
import Image
img = Image.open('./data/training/subject01.glasses.pgm')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-e90bece9f1d9> in <module>()
# ----> 1 import Image
#       2 img = Image.open('./data/training/subject01.glasses.pgm')
#
# ImportError: No module named Image
